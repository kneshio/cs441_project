# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ed = pd.read_excel('data/Education2023.xlsx',skiprows=3)
pop=pd.read_excel('data/PopulationEstimates.xlsx',skiprows=4)
pov=pd.read_excel('data/Poverty2023.xlsx',skiprows=4)
un=pd.read_excel('data/Unemployment2023.xlsx',skiprows=4)

# %%
ed.columns.to_list()
# Out:
# ['FIPS Code',
#  'State',
#  'Area name',
#  '2013 Urban Influence Code',
#  '2024 Urban Influence Code',
#  '2013 Rural-urban Continuum Code',
#  '2023 Rural-urban Continuum Code',
#  'Less than a high school diploma, 1970',
#  'High school diploma only, 1970',
#  'Some college (1-3 years), 1970',
#  'Four years of college or higher, 1970',
#  'Percent of adults with less than a high school diploma, 1970',
#  'Percent of adults with a high school diploma only, 1970',
#  'Percent of adults completing some college (1-3 years), 1970',
#  'Percent of adults completing four years of college or higher, 1970',
#  'Less than a high school diploma, 1980',
#  'High school diploma only, 1980',
#  'Some college (1-3 years), 1980',
#  'Four years of college or higher, 1980',
#  'Percent of adults with less than a high school diploma, 1980',
#  'Percent of adults with a high school diploma only, 1980',
#  'Percent of adults completing some college (1-3 years), 1980',
#  'Percent of adults completing four years of college or higher, 1980',
#  'Less than high school graduate, 1990',
#  'High school graduate (or equivalency), 1990',
#  'Some college or associate degree, 1990',
#  "Bachelor's degree or higher, 1990",
#  'Percent of adults who are not high school graduates, 1990',
#  'Percent of adults who are high school graduates (or equivalent), 1990',
#  'Percent of adults completing some college or associate degree, 1990',
#  "Percent of adults with a bachelor's degree or higher, 1990",
#  'Less than high school graduate, 2000',
#  'High school graduate (or equivalency), 2000',
#  'Some college or associate degree, 2000',
#  "Bachelor's degree or higher, 2000",
#  'Percent of adults who are not high school graduates, 2000',
#  'Percent of adults who are high school graduates (or equivalent), 2000',
#  'Percent of adults completing some college or associate degree, 2000',
#  "Percent of adults with a bachelor's degree or higher, 2000",
#  'Less than high school graduate, 2008-12',
#  'High school graduate (or equivalency), 2008-12',
#  'Some college or associate degree, 2008-12',
#  "Bachelor's degree or higher, 2008-12",
#  'Percent of adults who are not high school graduates, 2008-12',
#  'Percent of adults who are high school graduates (or equivalent), 2008-12',
#  'Percent of adults completing some college or associate degree, 2008-12',
#  "Percent of adults with a bachelor's degree or higher, 2008-12",
#  'Less than high school graduate, 2019-23',
#  'High school graduate (or equivalency), 2019-23',
#  'Some college or associate degree, 2019-23',
#  "Bachelor's degree or higher, 2019-23",
#  'Percent of adults who are not high school graduates, 2019-23',
#  'Percent of adults who are high school graduates (or equivalent), 2019-23',
#  'Percent of adults completing some college or associate degree, 2019-23',
#  "Percent of adults with a bachelor's degree or higher, 2019-23"]

# %%
ed_columns_to_keep = [
    "FIPS Code", "State", "Area name",  # Geographic Identifiers
    "2024 Urban Influence Code", "2023 Rural-urban Continuum Code",  # Urbanization & Influence
    # Educational Attainment, 2019-2023
    "Percent of adults who are not high school graduates, 2019-23",
    "Percent of adults who are high school graduates (or equivalent), 2019-23",
    "Percent of adults completing some college or associate degree, 2019-23",
    "Percent of adults with a bachelor's degree or higher, 2019-23",
    # Educational Attainment, 2008-2012
    # "Percent of adults who are not high school graduates, 2008-12",
    # "Percent of adults who are high school graduates (or equivalent), 2008-12",
    # "Percent of adults completing some college or associate degree, 2008-12",
    # "Percent of adults with a bachelor's degree or higher, 2008-12",
    # # Educational Attainment, 2000
    # "Percent of adults who are not high school graduates, 2000",
    # "Percent of adults who are high school graduates (or equivalent), 2000",
    # "Percent of adults completing some college or associate degree, 2000",
    # "Percent of adults with a bachelor's degree or higher, 2000",
    # # Educational Attainment, 1990
    # "Percent of adults who are not high school graduates, 1990",
    # "Percent of adults who are high school graduates (or equivalent), 1990",
    # "Percent of adults completing some college or associate degree, 1990",
    # "Percent of adults with a bachelor's degree or higher, 1990",
    # # Educational Attainment, 1980
    # "Percent of adults with less than a high school diploma, 1980",
    # "Percent of adults with a high school diploma only, 1980",
    # "Percent of adults completing some college (1-3 years), 1980",
    # "Percent of adults completing four years of college or higher, 1980",
    # # Educational Attainment, 1970
    # "Percent of adults with less than a high school diploma, 1970",
    # "Percent of adults with a high school diploma only, 1970",
    # "Percent of adults completing some college (1-3 years), 1970",
    # "Percent of adults completing four years of college or higher, 1970"
]
ed_filtered=ed[ed_columns_to_keep]

# %%
ed_filtered
# Out:
#       FIPS Code State            Area name  2024 Urban Influence Code  \
# 0             0    US        United States                        NaN
# 1          1000    AL              Alabama                        NaN
# 2          1001    AL       Autauga County                        4.0
# 3          1003    AL       Baldwin County                        4.0
# 4          1005    AL       Barbour County                        5.0
# ...         ...   ...                  ...                        ...
# 3289      72145    PR  Vega Baja Municipio                        1.0
# 3290      72147    PR    Vieques Municipio                        3.0
# 3291      72149    PR   Villalba Municipio                        4.0
# 3292      72151    PR    Yabucoa Municipio                        1.0
# 3293      72153    PR      Yauco Municipio                        4.0
#
#       2023 Rural-urban Continuum Code  \
# 0                                 NaN
# 1                                 NaN
# 2                                 2.0
# 3                                 3.0
# 4                                 6.0
# ...                               ...
# 3289                              1.0
# 3290                              6.0
# 3291                              2.0
# 3292                              1.0
# 3293                              2.0
#
#       Percent of adults who are not high school graduates, 2019-23  \
# 0                                             10.607067
# 1                                             11.871959
# 2                                              9.721098
# 3                                              8.268600
# 4                                             22.186295
# ...                                                 ...
# 3289                                          22.492099
# 3290                                          30.139489
# 3291                                          21.146194
# 3292                                          25.505929
# 3293                                          20.485207
#
#       Percent of adults who are high school graduates (or equivalent), 2019-23  \
# 0                                             26.194137
# 1                                             30.344616
# 2                                             32.675939
# 3                                             27.542038
# 4                                             37.604947
# ...                                                 ...
# 3289                                          28.902770
# 3290                                          47.691797
# 3291                                          31.895777
# 3292                                          25.933850
# 3293                                          33.960552
#
#       Percent of adults completing some college or associate degree, 2019-23  \
# 0                                             28.197846
# 1                                             30.028286
# 2                                             29.320284
# 3                                             31.391725
# 4                                             28.744044
# ...                                                 ...
# 3289                                          23.656770
# 3290                                           9.797409
# 3291                                          24.476961
# 3292                                          30.199697
# 3293                                          18.437870
#
#       Percent of adults with a bachelor's degree or higher, 2019-23
# 0                                             35.000950
# 1                                             27.755139
# 2                                             28.282680
# 3                                             32.797637
# 4                                             11.464715
# ...                                                 ...
# 3289                                          24.948361
# 3290                                          12.371305
# 3291                                          22.481068
# 3292                                          18.360524
# 3293                                          27.116371
#
# [3294 rows x 9 columns]

# %%
pov.columns.to_list()
# Out:
# ['FIPS_Code',
#  'Stabr',
#  'Area_Name',
#  'Rural_Urban_Continuum_Code_2013',
#  'Urban_Influence_Code_2013',
#  'Rural_Urban_Continuum_Code_2023',
#  'Urban_Influence_Code_2024',
#  'POVALL_2023',
#  'CI90LBALL_2023',
#  'CI90UBALL_2023',
#  'PCTPOVALL_2023',
#  'CI90LBALLP_2023',
#  'CI90UBALLP_2023',
#  'POV017_2023',
#  'CI90LB017_2023',
#  'CI90UB017_2023',
#  'PCTPOV017_2023',
#  'CI90LB017P_2023',
#  'CI90UB017P_2023',
#  'POV517_2023',
#  'CI90LB517_2023',
#  'CI90UB517_2023',
#  'PCTPOV517_2023',
#  'CI90LB517P_2023',
#  'CI90UB517P_2023',
#  'MEDHHINC_2023',
#  'CI90LBINC_2023',
#  'CI90UBINC_2023',
#  'POV04_2023',
#  'CI90LB04_2023',
#  'CI90UB04_2023',
#  'PCTPOV04_2023',
#  'CI90LB04P_2023',
#  'CI90UB04P_2023']

# %%
pov_columns_to_keep = [
    # Geographic Identifiers
    "FIPS_Code", "Stabr", "Area_Name",
    # Urbanization & Influence
    "Rural_Urban_Continuum_Code_2023", "Urban_Influence_Code_2024",
    # Economic Indicators/Poverty Metrics
    "MEDHHINC_2023", "PCTPOVALL_2023", "PCTPOV017_2023",
    "PCTPOV517_2023", "PCTPOV04_2023"
]
pov_filtered=pov[pov_columns_to_keep]

# %%
pov_filtered
# Out:
#       FIPS_Code Stabr          Area_Name  Rural_Urban_Continuum_Code_2023  \
# 0             0    US      United States                              NaN
# 1          1000    AL            Alabama                              NaN
# 2          1001    AL     Autauga County                              2.0
# 3          1003    AL     Baldwin County                              3.0
# 4          1005    AL     Barbour County                              6.0
# ...         ...   ...                ...                              ...
# 3191      56037    WY  Sweetwater County                              5.0
# 3192      56039    WY       Teton County                              7.0
# 3193      56041    WY       Uinta County                              7.0
# 3194      56043    WY    Washakie County                              9.0
# 3195      56045    WY      Weston County                              9.0
#
#       Urban_Influence_Code_2024  MEDHHINC_2023  PCTPOVALL_2023  \
# 0                           NaN        77719.0            12.5
# 1                           NaN        62248.0            15.7
# 2                           4.0        68857.0            11.7
# 3                           4.0        74248.0            10.0
# 4                           5.0        45298.0            25.5
# ...                         ...            ...             ...
# 3191                        7.0        76442.0            10.0
# 3192                        7.0       130156.0             6.2
# 3193                        7.0        79086.0            10.3
# 3194                        9.0        62794.0            12.3
# 3195                        9.0        66429.0            11.4
#
#       PCTPOV017_2023  PCTPOV517_2023  PCTPOV04_2023
# 0               16.0            15.3           16.8
# 1               21.3            20.2           23.2
# 2               17.0            16.7            NaN
# 3               14.1            13.0            NaN
# 4               34.8            33.2            NaN
# ...              ...             ...            ...
# 3191            11.5            10.4            NaN
# 3192             5.7             5.3            NaN
# 3193            11.4             9.8            NaN
# 3194            17.3            17.2            NaN
# 3195            14.0            12.6            NaN
#
# [3196 rows x 10 columns]

# %%
pop.columns.to_list()
# Out:
# ['FIPStxt',
#  'State',
#  'Area_Name',
#  'Rural_Urban_Continuum_Code_2013',
#  'Rural_Urban_Continuum_Code_2023',
#  'Urban_Influence_2013',
#  'Economic_typology_2015',
#  'CENSUS_2020_POP',
#  'ESTIMATES_BASE_2020',
#  'POP_ESTIMATE_2020',
#  'POP_ESTIMATE_2021',
#  'POP_ESTIMATE_2022',
#  'POP_ESTIMATE_2023',
#  'N_POP_CHG_2020',
#  'N_POP_CHG_2021',
#  'N_POP_CHG_2022',
#  'N_POP_CHG_2023',
#  'BIRTHS_2020',
#  'BIRTHS_2021',
#  'BIRTHS_2022',
#  'BIRTHS_2023',
#  'DEATHS_2020',
#  'DEATHS_2021',
#  'DEATHS_2022',
#  'DEATHS_2023',
#  'NATURAL_CHG_2020',
#  'NATURAL_CHG_2021',
#  'NATURAL_CHG_2022',
#  'NATURAL_CHG_2023',
#  'INTERNATIONAL_MIG_2020',
#  'INTERNATIONAL_MIG_2021',
#  'INTERNATIONAL_MIG_2022',
#  'INTERNATIONAL_MIG_2023',
#  'DOMESTIC_MIG_2020',
#  'DOMESTIC_MIG_2021',
#  'DOMESTIC_MIG_2022',
#  'DOMESTIC_MIG_2023',
#  'NET_MIG_2020',
#  'NET_MIG_2021',
#  'NET_MIG_2022',
#  'NET_MIG_2023',
#  'RESIDUAL_2020',
#  'RESIDUAL_2021',
#  'RESIDUAL_2022',
#  'RESIDUAL_2023',
#  'GQ_ESTIMATES_BASE_2020',
#  'GQ_ESTIMATES_2020',
#  'GQ_ESTIMATES_2021',
#  'GQ_ESTIMATES_2022',
#  'GQ_ESTIMATES_2023',
#  'R_BIRTH_2021',
#  'R_BIRTH_2022',
#  'R_BIRTH_2023',
#  'R_DEATH_2021',
#  'R_DEATH_2022',
#  'R_DEATH_2023',
#  'R_NATURAL_CHG_2021',
#  'R_NATURAL_CHG_2022',
#  'R_NATURAL_CHG_2023',
#  'R_INTERNATIONAL_MIG_2021',
#  'R_INTERNATIONAL_MIG_2022',
#  'R_INTERNATIONAL_MIG_2023',
#  'R_DOMESTIC_MIG_2021',
#  'R_DOMESTIC_MIG_2022',
#  'R_DOMESTIC_MIG_2023',
#  'R_NET_MIG_2021',
#  'R_NET_MIG_2022',
#  'R_NET_MIG_2023']

# %%
pop_columns_to_keep = [
    # Geographic Identifiers
    "FIPStxt", "State", "Area_Name",
    # Economic Indicators
    "Economic_typology_2015",
    # Urbanization & Influence
    "Rural_Urban_Continuum_Code_2023", "Urban_Influence_2013",
    # Population Metrics
    "CENSUS_2020_POP", "ESTIMATES_BASE_2020",
    # 2020-2023 Metrics
    "POP_ESTIMATE_2021", "N_POP_CHG_2021", "BIRTHS_2021",
    "DEATHS_2021", "NATURAL_CHG_2021", "INTERNATIONAL_MIG_2021",
    "DOMESTIC_MIG_2021", "NET_MIG_2021", "R_BIRTH_2021", "R_DEATH_2021",
    "R_NATURAL_CHG_2021", "R_INTERNATIONAL_MIG_2021", "R_DOMESTIC_MIG_2021", "R_NET_MIG_2021"
]
pop_filtered=pop[pop_columns_to_keep]

# %%
pop_filtered
# Out:
#       FIPStxt State            Area_Name  Economic_typology_2015  \
# 0           0    US        United States                     NaN
# 1        1000    AL              Alabama                     NaN
# 2        1001    AL       Autauga County                     0.0
# 3        1003    AL       Baldwin County                     5.0
# 4        1005    AL       Barbour County                     3.0
# ...       ...   ...                  ...                     ...
# 3278    72145    PR  Vega Baja Municipio                     NaN
# 3279    72147    PR    Vieques Municipio                     NaN
# 3280    72149    PR   Villalba Municipio                     NaN
# 3281    72151    PR    Yabucoa Municipio                     NaN
# 3282    72153    PR      Yauco Municipio                     NaN
#
#       Rural_Urban_Continuum_Code_2023  Urban_Influence_2013  CENSUS_2020_POP  \
# 0                                 NaN                   NaN      331449281.0
# 1                                 NaN                   NaN        5024279.0
# 2                                 2.0                   2.0          58805.0
# 3                                 3.0                   2.0         231767.0
# 4                                 6.0                   6.0          25223.0
# ...                               ...                   ...              ...
# 3278                              1.0                   1.0          54414.0
# 3279                              6.0                  12.0           8249.0
# 3280                              2.0                   2.0          22093.0
# 3281                              1.0                   1.0          30426.0
# 3282                              2.0                   2.0          34172.0
#
#       ESTIMATES_BASE_2020  POP_ESTIMATE_2021  N_POP_CHG_2021  ...  \
# 0             331464948.0        332048977.0        522044.0  ...
# 1               5024294.0          5050380.0         18516.0  ...
# 2                 58809.0            59203.0           288.0  ...
# 3                231768.0           239439.0          6212.0  ...
# 4                 25229.0            24533.0          -436.0  ...
# ...                   ...                ...             ...  ...
# 3278              54414.0            54227.0             NaN  ...
# 3279               8249.0             8171.0             NaN  ...
# 3280              22093.0            21817.0             NaN  ...
# 3281              30426.0            29944.0             NaN  ...
# 3282              34172.0            33603.0             NaN  ...
#
#       NATURAL_CHG_2021  INTERNATIONAL_MIG_2021  DOMESTIC_MIG_2021  \
# 0             146036.0                376008.0                0.0
# 1             -11951.0                  1806.0            27715.0
# 2                -10.0                    15.0              242.0
# 3               -611.0                   105.0             6972.0
# 4               -120.0                     0.0             -313.0
# ...                ...                     ...                ...
# 3278               NaN                     NaN                NaN
# 3279               NaN                     NaN                NaN
# 3280               NaN                     NaN                NaN
# 3281               NaN                     NaN                NaN
# 3282               NaN                     NaN                NaN
#
#       NET_MIG_2021  R_BIRTH_2021  R_DEATH_2021  R_NATURAL_CHG_2021  \
# 0         376008.0          10.8          10.4                 0.4
# 1          29521.0          11.3          13.7                -2.4
# 2            257.0          11.6          11.8                -0.2
# 3           7077.0           9.9          12.5                -2.6
# 4           -313.0          10.9          15.8                -4.8
# ...            ...           ...           ...                 ...
# 3278           NaN           NaN           NaN                 NaN
# 3279           NaN           NaN           NaN                 NaN
# 3280           NaN           NaN           NaN                 NaN
# 3281           NaN           NaN           NaN                 NaN
# 3282           NaN           NaN           NaN                 NaN
#
#       R_INTERNATIONAL_MIG_2021  R_DOMESTIC_MIG_2021  R_NET_MIG_2021
# 0                          1.1                  0.0             1.1
# 1                          0.4                  5.5             5.9
# 2                          0.3                  4.1             4.4
# 3                          0.4                 29.5            29.9
# 4                          0.0                -12.6           -12.6
# ...                        ...                  ...             ...
# 3278                       NaN                  NaN             NaN
# 3279                       NaN                  NaN             NaN
# 3280                       NaN                  NaN             NaN
# 3281                       NaN                  NaN             NaN
# 3282                       NaN                  NaN             NaN
#
# [3283 rows x 22 columns]

# %%
un.columns.to_list()
# Out:
# ['FIPS_Code',
#  'State',
#  'Area_Name',
#  'Rural_Urban_Continuum_Code_2023',
#  'Urban_Influence_Code_2013',
#  'Metro_2023',
#  'Civilian_labor_force_2000',
#  'Employed_2000',
#  'Unemployed_2000',
#  'Unemployment_rate_2000',
#  'Civilian_labor_force_2001',
#  'Employed_2001',
#  'Unemployed_2001',
#  'Unemployment_rate_2001',
#  'Civilian_labor_force_2002',
#  'Employed_2002',
#  'Unemployed_2002',
#  'Unemployment_rate_2002',
#  'Civilian_labor_force_2003',
#  'Employed_2003',
#  'Unemployed_2003',
#  'Unemployment_rate_2003',
#  'Civilian_labor_force_2004',
#  'Employed_2004',
#  'Unemployed_2004',
#  'Unemployment_rate_2004',
#  'Civilian_labor_force_2005',
#  'Employed_2005',
#  'Unemployed_2005',
#  'Unemployment_rate_2005',
#  'Civilian_labor_force_2006',
#  'Employed_2006',
#  'Unemployed_2006',
#  'Unemployment_rate_2006',
#  'Civilian_labor_force_2007',
#  'Employed_2007',
#  'Unemployed_2007',
#  'Unemployment_rate_2007',
#  'Civilian_labor_force_2008',
#  'Employed_2008',
#  'Unemployed_2008',
#  'Unemployment_rate_2008',
#  'Civilian_labor_force_2009',
#  'Employed_2009',
#  'Unemployed_2009',
#  'Unemployment_rate_2009',
#  'Civilian_labor_force_2010',
#  'Employed_2010',
#  'Unemployed_2010',
#  'Unemployment_rate_2010',
#  'Civilian_labor_force_2011',
#  'Employed_2011',
#  'Unemployed_2011',
#  'Unemployment_rate_2011',
#  'Civilian_labor_force_2012',
#  'Employed_2012',
#  'Unemployed_2012',
#  'Unemployment_rate_2012',
#  'Civilian_labor_force_2013',
#  'Employed_2013',
#  'Unemployed_2013',
#  'Unemployment_rate_2013',
#  'Civilian_labor_force_2014',
#  'Employed_2014',
#  'Unemployed_2014',
#  'Unemployment_rate_2014',
#  'Civilian_labor_force_2015',
#  'Employed_2015',
#  'Unemployed_2015',
#  'Unemployment_rate_2015',
#  'Civilian_labor_force_2016',
#  'Employed_2016',
#  'Unemployed_2016',
#  'Unemployment_rate_2016',
#  'Civilian_labor_force_2017',
#  'Employed_2017',
#  'Unemployed_2017',
#  'Unemployment_rate_2017',
#  'Civilian_labor_force_2018',
#  'Employed_2018',
#  'Unemployed_2018',
#  'Unemployment_rate_2018',
#  'Civilian_labor_force_2019',
#  'Employed_2019',
#  'Unemployed_2019',
#  'Unemployment_rate_2019',
#  'Civilian_labor_force_2020',
#  'Employed_2020',
#  'Unemployed_2020',
#  'Unemployment_rate_2020',
#  'Civilian_labor_force_2021',
#  'Employed_2021',
#  'Unemployed_2021',
#  'Unemployment_rate_2021',
#  'Civilian_labor_force_2022',
#  'Employed_2022',
#  'Unemployed_2022',
#  'Unemployment_rate_2022',
#  'Civilian_labor_force_2023',
#  'Employed_2023',
#  'Unemployed_2023',
#  'Unemployment_rate_2023',
#  'Median_Household_Income_2022',
#  'Med_HH_Income_Percent_of_State_Total_2022']

# %%
un_columns_to_keep = [
    # Geographic Identifiers
    "FIPS_Code", "State", "Area_Name",
    # Economic Indicators
    "Median_Household_Income_2022", "Med_HH_Income_Percent_of_State_Total_2022",
    # Urbanization & Influence
    "Rural_Urban_Continuum_Code_2023", "Urban_Influence_Code_2013", "Metro_2023",
    # Employment Metrics over 24 years
    "Civilian_labor_force_2023", "Employed_2023", "Unemployed_2023", "Unemployment_rate_2023"
]
un_filtered=un[un_columns_to_keep]

# %%
un_filtered
# Out:
#       FIPS_Code State                Area_Name  Median_Household_Income_2022  \
# 0             0    US            United States                       74755.0
# 1          1000    AL                  Alabama                       59703.0
# 2          1001    AL       Autauga County, AL                       70148.0
# 3          1003    AL       Baldwin County, AL                       71704.0
# 4          1005    AL       Barbour County, AL                       41151.0
# ...         ...   ...                      ...                           ...
# 3281      72145    PR  Vega Baja Municipio, PR                           NaN
# 3282      72147    PR    Vieques Municipio, PR                           NaN
# 3283      72149    PR   Villalba Municipio, PR                           NaN
# 3284      72151    PR    Yabucoa Municipio, PR                           NaN
# 3285      72153    PR      Yauco Municipio, PR                           NaN
#
#       Med_HH_Income_Percent_of_State_Total_2022  \
# 0                                           NaN
# 1                                         100.0
# 2                                         117.5
# 3                                         120.1
# 4                                          68.9
# ...                                         ...
# 3281                                        NaN
# 3282                                        NaN
# 3283                                        NaN
# 3284                                        NaN
# 3285                                        NaN
#
#       Rural_Urban_Continuum_Code_2023  Urban_Influence_Code_2013  Metro_2023  \
# 0                                 NaN                        NaN         NaN
# 1                                 NaN                        NaN         NaN
# 2                                 2.0                        2.0         1.0
# 3                                 3.0                        2.0         1.0
# 4                                 6.0                        6.0         0.0
# ...                               ...                        ...         ...
# 3281                              1.0                        1.0         1.0
# 3282                              6.0                       12.0         0.0
# 3283                              2.0                        2.0         1.0
# 3284                              1.0                        1.0         1.0
# 3285                              2.0                        2.0         1.0
#
#       Civilian_labor_force_2023  Employed_2023  Unemployed_2023  \
# 0                   166689556.0    160623678.0        6065878.0
# 1                     2308131.0      2250472.0          57659.0
# 2                       27000.0        26409.0            591.0
# 3                      104409.0       102029.0           2380.0
# 4                        7944.0         7592.0            352.0
# ...                         ...            ...              ...
# 3281                    14333.0        13276.0           1057.0
# 3282                     2720.0         2603.0            117.0
# 3283                     7819.0         6988.0            831.0
# 3284                     9365.0         8583.0            782.0
# 3285                    10488.0         9278.0           1210.0
#
#       Unemployment_rate_2023
# 0                        3.6
# 1                        2.5
# 2                        2.2
# 3                        2.3
# 4                        4.4
# ...                      ...
# 3281                     7.4
# 3282                     4.3
# 3283                    10.6
# 3284                     8.4
# 3285                    11.5
#
# [3286 rows x 12 columns]

# %%
def correlated_pairs(df, threshold=0.0):
    df=df.select_dtypes(include=['number'])
    # Calculate correlations
    corr_matrix = df.corr()
    
    # Convert to long format, keeping only high correlations
    correlations = []
    for col1 in corr_matrix.columns:
        for col2 in corr_matrix.columns:
            if col1 < col2:  # Avoid duplicate pairs and self-correlations
                corr_value = corr_matrix.loc[col1, col2]
                if abs(corr_value) >= threshold:
                    correlations.append({
                        'col1': col1,
                        'col2': col2,
                        'correlation': corr_value
                    })
    
    # Sort by absolute correlation value
    result = pd.DataFrame(correlations)
    if len(result) > 0:
        return result.sort_values(by='correlation', key=abs, ascending=False)
    else:
        print(f"No correlations found above threshold of {threshold}")
        return result

# %%
#ed_filtered
#pov_filtered
#pop_filtered
#un_filtered
correlated_pairs(ed_filtered)
# Out:
#                                                  col1  \
# 10                    2023 Rural-urban Continuum Code
# 17  Percent of adults who are high school graduate...
# 15  Percent of adults who are not high school grad...
# 14                    2023 Rural-urban Continuum Code
# 18  Percent of adults completing some college or a...
# 12                    2023 Rural-urban Continuum Code
# 8                           2024 Urban Influence Code
# 16  Percent of adults who are high school graduate...
# 6                           2024 Urban Influence Code
# 7                           2024 Urban Influence Code
# 13                    2023 Rural-urban Continuum Code
# 19  Percent of adults completing some college or a...
# 20  Percent of adults completing some college or a...
# 2                                           FIPS Code
# 11                    2023 Rural-urban Continuum Code
# 0                                           FIPS Code
# 4                           2024 Urban Influence Code
# 9                     2023 Rural-urban Continuum Code
# 5                           2024 Urban Influence Code
# 3                                           FIPS Code
# 1                                           FIPS Code
#
#                                                  col2  correlation
# 10                          2024 Urban Influence Code     0.832606
# 17  Percent of adults with a bachelor's degree or ...    -0.807936
# 15  Percent of adults with a bachelor's degree or ...    -0.542152
# 14  Percent of adults with a bachelor's degree or ...    -0.425390
# 18  Percent of adults who are not high school grad...    -0.411356
# 12  Percent of adults who are high school graduate...     0.352543
# 8   Percent of adults with a bachelor's degree or ...    -0.332747
# 16  Percent of adults who are not high school grad...     0.265203
# 6   Percent of adults who are high school graduate...     0.231653
# 7   Percent of adults completing some college or a...     0.227366
# 13  Percent of adults completing some college or a...     0.173717
# 19  Percent of adults who are high school graduate...    -0.173124
# 20  Percent of adults with a bachelor's degree or ...    -0.168716
# 2   Percent of adults completing some college or a...    -0.137860
# 11  Percent of adults who are not high school grad...     0.118642
# 0   Percent of adults who are not high school grad...     0.097741
# 4                                           FIPS Code    -0.089236
# 9                                           FIPS Code    -0.071913
# 5   Percent of adults who are not high school grad...     0.065380
# 3   Percent of adults with a bachelor's degree or ...     0.032722
# 1   Percent of adults who are high school graduate...    -0.019380

# %%
correlated_pairs(pov_filtered)
# Out:
#                                col1                             col2  \
# 19                   PCTPOV017_2023                   PCTPOV517_2023
# 20                   PCTPOV017_2023                    PCTPOV04_2023
# 25                    PCTPOV04_2023                   PCTPOV517_2023
# 24                    PCTPOV04_2023                   PCTPOVALL_2023
# 18                   PCTPOV017_2023                   PCTPOVALL_2023
# 23                   PCTPOV517_2023                   PCTPOVALL_2023
# 7   Rural_Urban_Continuum_Code_2023        Urban_Influence_Code_2024
# 11                    MEDHHINC_2023                   PCTPOV017_2023
# 10                    MEDHHINC_2023                   PCTPOVALL_2023
# 12                    MEDHHINC_2023                   PCTPOV517_2023
# 13                    MEDHHINC_2023                    PCTPOV04_2023
# 8                     MEDHHINC_2023  Rural_Urban_Continuum_Code_2023
# 9                     MEDHHINC_2023        Urban_Influence_Code_2024
# 16                   PCTPOV017_2023  Rural_Urban_Continuum_Code_2023
# 21                   PCTPOV517_2023  Rural_Urban_Continuum_Code_2023
# 14                   PCTPOVALL_2023  Rural_Urban_Continuum_Code_2023
# 15                   PCTPOVALL_2023        Urban_Influence_Code_2024
# 17                   PCTPOV017_2023        Urban_Influence_Code_2024
# 22                   PCTPOV517_2023        Urban_Influence_Code_2024
# 6                         FIPS_Code                    PCTPOV04_2023
# 3                         FIPS_Code                   PCTPOVALL_2023
# 4                         FIPS_Code                   PCTPOV017_2023
# 5                         FIPS_Code                   PCTPOV517_2023
# 1                         FIPS_Code        Urban_Influence_Code_2024
# 2                         FIPS_Code                    MEDHHINC_2023
# 0                         FIPS_Code  Rural_Urban_Continuum_Code_2023
#
#     correlation
# 19     0.990505
# 20     0.987752
# 25     0.976137
# 24     0.972464
# 18     0.938458
# 23     0.925837
# 7      0.829060
# 11    -0.769964
# 10    -0.762752
# 12    -0.758104
# 13    -0.670108
# 8     -0.475163
# 9     -0.449768
# 16     0.293454
# 21     0.292783
# 14     0.280680
# 15     0.258754
# 17     0.249724
# 22     0.246081
# 6     -0.107146
# 3     -0.072530
# 4     -0.068969
# 5     -0.060157
# 1     -0.032924
# 2      0.025798
# 0     -0.012154

# %%
correlated_pairs(pop_filtered)
# Out:
#                                col1                    col2  correlation
# 1                   CENSUS_2020_POP     ESTIMATES_BASE_2020     1.000000
# 6               ESTIMATES_BASE_2020       POP_ESTIMATE_2021     0.999997
# 2                   CENSUS_2020_POP       POP_ESTIMATE_2021     0.999997
# 11                      BIRTHS_2021       POP_ESTIMATE_2021     0.999835
# 9                       BIRTHS_2021         CENSUS_2020_POP     0.999813
# 10                      BIRTHS_2021     ESTIMATES_BASE_2020     0.999813
# 16                      DEATHS_2021       POP_ESTIMATE_2021     0.999527
# 3                   CENSUS_2020_POP             DEATHS_2021     0.999492
# 15                      DEATHS_2021     ESTIMATES_BASE_2020     0.999492
# 12                      BIRTHS_2021             DEATHS_2021     0.999251
# 26              R_DOMESTIC_MIG_2021          R_NET_MIG_2021     0.998629
# 20           INTERNATIONAL_MIG_2021       POP_ESTIMATE_2021     0.995242
# 5                   CENSUS_2020_POP  INTERNATIONAL_MIG_2021     0.995214
# 8               ESTIMATES_BASE_2020  INTERNATIONAL_MIG_2021     0.995210
# 14                      BIRTHS_2021  INTERNATIONAL_MIG_2021     0.994889
# 18                      DEATHS_2021  INTERNATIONAL_MIG_2021     0.993847
# 24                     NET_MIG_2021          N_POP_CHG_2021     0.973143
# 23                DOMESTIC_MIG_2021            NET_MIG_2021     0.882341
# 25                     R_DEATH_2021      R_NATURAL_CHG_2021    -0.857122
# 0   Rural_Urban_Continuum_Code_2023    Urban_Influence_2013     0.847701
# 22                DOMESTIC_MIG_2021          N_POP_CHG_2021     0.774628
# 21           INTERNATIONAL_MIG_2021        NATURAL_CHG_2021     0.764448
# 13                      BIRTHS_2021        NATURAL_CHG_2021     0.763392
# 4                   CENSUS_2020_POP        NATURAL_CHG_2021     0.756140
# 7               ESTIMATES_BASE_2020        NATURAL_CHG_2021     0.756112
# 19                 NATURAL_CHG_2021       POP_ESTIMATE_2021     0.755906
# 17                      DEATHS_2021        NATURAL_CHG_2021     0.737823

# %%
correlated_pairs(un_filtered)
# Out:
#                                          col1  \
# 31                  Civilian_labor_force_2023
# 32                  Civilian_labor_force_2023
# 40                              Employed_2023
# 21                                 Metro_2023
# 18            Rural_Urban_Continuum_Code_2023
# 12  Med_HH_Income_Percent_of_State_Total_2022
# 22                                 Metro_2023
# 7                Median_Household_Income_2022
# 13  Med_HH_Income_Percent_of_State_Total_2022
# 15  Med_HH_Income_Percent_of_State_Total_2022
# 9                Median_Household_Income_2022
# 14  Med_HH_Income_Percent_of_State_Total_2022
# 8                Median_Household_Income_2022
# 17  Med_HH_Income_Percent_of_State_Total_2022
# 37                              Employed_2023
# 28                  Civilian_labor_force_2023
# 11               Median_Household_Income_2022
# 39                              Employed_2023
# 30                  Civilian_labor_force_2023
# 38                              Employed_2023
# 19            Rural_Urban_Continuum_Code_2023
# 29                  Civilian_labor_force_2023
# 23                                 Metro_2023
# 42                            Unemployed_2023
# 36                              Employed_2023
# 27                  Civilian_labor_force_2023
# 6                                   FIPS_Code
# 16  Med_HH_Income_Percent_of_State_Total_2022
# 3                                   FIPS_Code
# 2                                   FIPS_Code
# 4                                   FIPS_Code
# 35                              Employed_2023
# 26                  Civilian_labor_force_2023
# 10               Median_Household_Income_2022
# 5                                   FIPS_Code
# 25                  Civilian_labor_force_2023
# 34                              Employed_2023
# 44                     Unemployment_rate_2023
# 0                                   FIPS_Code
# 20            Rural_Urban_Continuum_Code_2023
# 1                                   FIPS_Code
# 43                            Unemployed_2023
# 24                                 Metro_2023
# 41                              Employed_2023
# 33                  Civilian_labor_force_2023
#
#                                          col2  correlation
# 31                              Employed_2023     0.999998
# 32                            Unemployed_2023     0.998910
# 40                            Unemployed_2023     0.998826
# 21            Rural_Urban_Continuum_Code_2023    -0.884642
# 18                  Urban_Influence_Code_2013     0.847672
# 12               Median_Household_Income_2022     0.827318
# 22                  Urban_Influence_Code_2013    -0.754921
# 7             Rural_Urban_Continuum_Code_2023    -0.466860
# 13            Rural_Urban_Continuum_Code_2023    -0.462733
# 15                                 Metro_2023     0.441780
# 9                                  Metro_2023     0.440356
# 14                  Urban_Influence_Code_2013    -0.400495
# 8                   Urban_Influence_Code_2013    -0.396766
# 17                     Unemployment_rate_2023    -0.371538
# 37            Rural_Urban_Continuum_Code_2023    -0.330722
# 28            Rural_Urban_Continuum_Code_2023    -0.329178
# 11                     Unemployment_rate_2023    -0.311788
# 39                                 Metro_2023     0.304928
# 30                                 Metro_2023     0.303502
# 38                  Urban_Influence_Code_2013    -0.284713
# 19                            Unemployed_2023    -0.284470
# 29                  Urban_Influence_Code_2013    -0.283389
# 23                            Unemployed_2023     0.262206
# 42                  Urban_Influence_Code_2013    -0.245052
# 36  Med_HH_Income_Percent_of_State_Total_2022     0.103891
# 27  Med_HH_Income_Percent_of_State_Total_2022     0.103091
# 6                      Unemployment_rate_2023     0.095224
# 16                            Unemployed_2023     0.082410
# 3                   Urban_Influence_Code_2013    -0.081238
# 2             Rural_Urban_Continuum_Code_2023    -0.072162
# 4                                  Metro_2023     0.059708
# 35               Median_Household_Income_2022     0.042698
# 26               Median_Household_Income_2022     0.042668
# 10                            Unemployed_2023     0.041847
# 5                             Unemployed_2023    -0.040167
# 25                                  FIPS_Code    -0.039584
# 34                                  FIPS_Code    -0.039560
# 44                  Urban_Influence_Code_2013    -0.029514
# 0                Median_Household_Income_2022     0.024793
# 20                     Unemployment_rate_2023    -0.012782
# 1   Med_HH_Income_Percent_of_State_Total_2022     0.005302
# 43                     Unemployment_rate_2023     0.004809
# 24                     Unemployment_rate_2023    -0.004730
# 41                     Unemployment_rate_2023    -0.001538
# 33                     Unemployment_rate_2023    -0.001306

# %%
correlated_pairs(ed_filtered)
# Out:
#                                                  col1  \
# 10                    2023 Rural-urban Continuum Code
# 17  Percent of adults who are high school graduate...
# 15  Percent of adults who are not high school grad...
# 14                    2023 Rural-urban Continuum Code
# 18  Percent of adults completing some college or a...
# 12                    2023 Rural-urban Continuum Code
# 8                           2024 Urban Influence Code
# 16  Percent of adults who are high school graduate...
# 6                           2024 Urban Influence Code
# 7                           2024 Urban Influence Code
# 13                    2023 Rural-urban Continuum Code
# 19  Percent of adults completing some college or a...
# 20  Percent of adults completing some college or a...
# 2                                           FIPS Code
# 11                    2023 Rural-urban Continuum Code
# 0                                           FIPS Code
# 4                           2024 Urban Influence Code
# 9                     2023 Rural-urban Continuum Code
# 5                           2024 Urban Influence Code
# 3                                           FIPS Code
# 1                                           FIPS Code
#
#                                                  col2  correlation
# 10                          2024 Urban Influence Code     0.832606
# 17  Percent of adults with a bachelor's degree or ...    -0.807936
# 15  Percent of adults with a bachelor's degree or ...    -0.542152
# 14  Percent of adults with a bachelor's degree or ...    -0.425390
# 18  Percent of adults who are not high school grad...    -0.411356
# 12  Percent of adults who are high school graduate...     0.352543
# 8   Percent of adults with a bachelor's degree or ...    -0.332747
# 16  Percent of adults who are not high school grad...     0.265203
# 6   Percent of adults who are high school graduate...     0.231653
# 7   Percent of adults completing some college or a...     0.227366
# 13  Percent of adults completing some college or a...     0.173717
# 19  Percent of adults who are high school graduate...    -0.173124
# 20  Percent of adults with a bachelor's degree or ...    -0.168716
# 2   Percent of adults completing some college or a...    -0.137860
# 11  Percent of adults who are not high school grad...     0.118642
# 0   Percent of adults who are not high school grad...     0.097741
# 4                                           FIPS Code    -0.089236
# 9                                           FIPS Code    -0.071913
# 5   Percent of adults who are not high school grad...     0.065380
# 3   Percent of adults with a bachelor's degree or ...     0.032722
# 1   Percent of adults who are high school graduate...    -0.019380

# %%
ed_filtered = ed_filtered.rename(columns={'FIPS Code': 'FIPS'})
pop_filtered = pop_filtered.rename(columns={'FIPStxt': 'FIPS'})
un_filtered = un_filtered.rename(columns={'FIPS_Code': 'FIPS'})
pov_filtered = pov_filtered.rename(columns={'FIPS_Code': 'FIPS'})

# Merge all dataframes on 'FIPS'
merged = ed_filtered.merge(pop_filtered, on='FIPS')\
                       .merge(un_filtered, on='FIPS')\
                       .merge(pov_filtered, on='FIPS')

# %%
merged
# Out:
#        FIPS State_x          Area name  2024 Urban Influence Code  \
# 0         0      US      United States                        NaN
# 1      1000      AL            Alabama                        NaN
# 2      1001      AL     Autauga County                        4.0
# 3      1003      AL     Baldwin County                        4.0
# 4      1005      AL     Barbour County                        5.0
# ...     ...     ...                ...                        ...
# 3190  56037      WY  Sweetwater County                        7.0
# 3191  56039      WY       Teton County                        7.0
# 3192  56041      WY       Uinta County                        7.0
# 3193  56043      WY    Washakie County                        9.0
# 3194  56045      WY      Weston County                        9.0
#
#       2023 Rural-urban Continuum Code  \
# 0                                 NaN
# 1                                 NaN
# 2                                 2.0
# 3                                 3.0
# 4                                 6.0
# ...                               ...
# 3190                              5.0
# 3191                              7.0
# 3192                              7.0
# 3193                              9.0
# 3194                              9.0
#
#       Percent of adults who are not high school graduates, 2019-23  \
# 0                                             10.607067
# 1                                             11.871959
# 2                                              9.721098
# 3                                              8.268600
# 4                                             22.186295
# ...                                                 ...
# 3190                                           7.468835
# 3191                                           2.840434
# 3192                                           5.393292
# 3193                                           8.580258
# 3194                                           8.399209
#
#       Percent of adults who are high school graduates (or equivalent), 2019-23  \
# 0                                             26.194137
# 1                                             30.344616
# 2                                             32.675939
# 3                                             27.542038
# 4                                             37.604947
# ...                                                 ...
# 3190                                          31.147245
# 3191                                          16.145920
# 3192                                          35.990140
# 3193                                          30.267224
# 3194                                          36.462451
#
#       Percent of adults completing some college or associate degree, 2019-23  \
# 0                                             28.197846
# 1                                             30.028286
# 2                                             29.320284
# 3                                             31.391725
# 4                                             28.744044
# ...                                                 ...
# 3190                                          41.008130
# 3191                                          19.793929
# 3192                                          37.297378
# 3193                                          39.120160
# 3194                                          37.094862
#
#       Percent of adults with a bachelor's degree or higher, 2019-23 State_y  \
# 0                                             35.000950                  US
# 1                                             27.755139                  AL
# 2                                             28.282680                  AL
# 3                                             32.797637                  AL
# 4                                             11.464715                  AL
# ...                                                 ...                 ...
# 3190                                          20.375790                  WY
# 3191                                          61.219716                  WY
# 3192                                          21.319190                  WY
# 3193                                          22.032358                  WY
# 3194                                          18.043478                  WY
#
#       ... Unemployment_rate_2023  Stabr          Area_Name  \
# 0     ...                    3.6     US      United States
# 1     ...                    2.5     AL            Alabama
# 2     ...                    2.2     AL     Autauga County
# 3     ...                    2.3     AL     Baldwin County
# 4     ...                    4.4     AL     Barbour County
# ...   ...                    ...    ...                ...
# 3190  ...                    3.3     WY  Sweetwater County
# 3191  ...                    2.1     WY       Teton County
# 3192  ...                    3.2     WY       Uinta County
# 3193  ...                    3.3     WY    Washakie County
# 3194  ...                    2.1     WY      Weston County
#
#       Rural_Urban_Continuum_Code_2023  Urban_Influence_Code_2024  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 2.0                        4.0
# 3                                 3.0                        4.0
# 4                                 6.0                        5.0
# ...                               ...                        ...
# 3190                              5.0                        7.0
# 3191                              7.0                        7.0
# 3192                              7.0                        7.0
# 3193                              9.0                        9.0
# 3194                              9.0                        9.0
#
#       MEDHHINC_2023  PCTPOVALL_2023  PCTPOV017_2023  PCTPOV517_2023  \
# 0           77719.0            12.5            16.0            15.3
# 1           62248.0            15.7            21.3            20.2
# 2           68857.0            11.7            17.0            16.7
# 3           74248.0            10.0            14.1            13.0
# 4           45298.0            25.5            34.8            33.2
# ...             ...             ...             ...             ...
# 3190        76442.0            10.0            11.5            10.4
# 3191       130156.0             6.2             5.7             5.3
# 3192        79086.0            10.3            11.4             9.8
# 3193        62794.0            12.3            17.3            17.2
# 3194        66429.0            11.4            14.0            12.6
#
#       PCTPOV04_2023
# 0              16.8
# 1              23.2
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3190            NaN
# 3191            NaN
# 3192            NaN
# 3193            NaN
# 3194            NaN
#
# [3195 rows x 50 columns]

# %%
mcorr = correlated_pairs(merged)
mcorr
# Out:
#                                 col1                               col2  \
# 738  Rural_Urban_Continuum_Code_2023  Rural_Urban_Continuum_Code_2023_x
# 210             Urban_Influence_2013          Urban_Influence_Code_2013
# 97   2023 Rural-urban Continuum Code  Rural_Urban_Continuum_Code_2023_y
# 104  2023 Rural-urban Continuum Code    Rural_Urban_Continuum_Code_2023
# 740  Rural_Urban_Continuum_Code_2023  Rural_Urban_Continuum_Code_2023_y
# ..                               ...                                ...
# 495                     NET_MIG_2021               Urban_Influence_2013
# 723                    Employed_2023             Unemployment_rate_2023
# 447           INTERNATIONAL_MIG_2021             Unemployment_rate_2023
# 7                               FIPS                     N_POP_CHG_2021
# 14                              FIPS           R_INTERNATIONAL_MIG_2021
#
#      correlation
# 738     1.000000
# 210     1.000000
# 97      1.000000
# 104     1.000000
# 740     1.000000
# ..           ...
# 495     0.001557
# 723     0.001394
# 447     0.001174
# 7      -0.000385
# 14      0.000226
#
# [850 rows x 3 columns]

# %%
mcorr[mcorr['correlation'] == 1]
# Out:
#                                   col1                               col2  \
# 738    Rural_Urban_Continuum_Code_2023  Rural_Urban_Continuum_Code_2023_x
# 210               Urban_Influence_2013          Urban_Influence_Code_2013
# 97     2023 Rural-urban Continuum Code  Rural_Urban_Continuum_Code_2023_y
# 104    2023 Rural-urban Continuum Code    Rural_Urban_Continuum_Code_2023
# 740    Rural_Urban_Continuum_Code_2023  Rural_Urban_Continuum_Code_2023_y
# 205  Rural_Urban_Continuum_Code_2023_x  Rural_Urban_Continuum_Code_2023_y
# 65           2024 Urban Influence Code          Urban_Influence_Code_2024
# 77     2023 Rural-urban Continuum Code  Rural_Urban_Continuum_Code_2023_x
#
#      correlation
# 738          1.0
# 210          1.0
# 97           1.0
# 104          1.0
# 740          1.0
# 205          1.0
# 65           1.0
# 77           1.0

# %%
mcorr[mcorr['correlation'] != 1]
# Out:
#                           col1                      col2  correlation
# 220            CENSUS_2020_POP       ESTIMATES_BASE_2020     1.000000
# 689  Civilian_labor_force_2023             Employed_2023     0.999998
# 258        ESTIMATES_BASE_2020         POP_ESTIMATE_2021     0.999997
# 221            CENSUS_2020_POP         POP_ESTIMATE_2021     0.999997
# 671  Civilian_labor_force_2023         POP_ESTIMATE_2021     0.999974
# ..                         ...                       ...          ...
# 495               NET_MIG_2021      Urban_Influence_2013     0.001557
# 723              Employed_2023    Unemployment_rate_2023     0.001394
# 447     INTERNATIONAL_MIG_2021    Unemployment_rate_2023     0.001174
# 7                         FIPS            N_POP_CHG_2021    -0.000385
# 14                        FIPS  R_INTERNATIONAL_MIG_2021     0.000226
#
# [842 rows x 3 columns]

# %%
# Filter the DataFrame to include only correlations above 0.8
high_corr = mcorr[mcorr['correlation'] > 0.8]

# Count the number of occurrences
high_corr_count = high_corr.shape[0]

# Display the result
print(f"Number of correlations above 0.8: {high_corr_count}")
# Out:
# Number of correlations above 0.8: 75
