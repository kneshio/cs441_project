# %% [markdown]
# # Initial Steps

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/data_merged_encoded.csv")
data
# Out:
#        FIPS  2024 Urban Influence Code  \
# 0      1001                  -0.426905
# 1      1003                  -0.426905
# 2      1005                  -0.037317
# 3      1007                  -1.595670
# 4      1009                  -1.595670
# ...     ...                        ...
# 3127  56037                   0.741860
# 3128  56039                   0.741860
# 3129  56041                   0.741860
# 3130  56043                   1.521036
# 3131  56045                   1.521036
#
#       Percent of adults who are not high school graduates, 2019-23  \
# 0                                             -0.278537
# 1                                             -0.543725
# 2                                              1.997280
# 3                                              1.536006
# 4                                              1.105865
# ...                                                 ...
# 3127                                          -0.689741
# 3128                                          -1.534765
# 3129                                          -1.068681
# 3130                                          -0.486824
# 3131                                          -0.519879
#
#       Percent of adults who are high school graduates (or equivalent), 2019-23  \
# 0                                             -0.151198
# 1                                             -0.822225
# 2                                              0.493048
# 3                                              0.953446
# 4                                              0.233289
# ...                                                 ...
# 3127                                          -0.351006
# 3128                                          -2.311755
# 3129                                           0.281985
# 3130                                          -0.466029
# 3131                                           0.343718
#
#       Percent of adults completing some college or associate degree, 2019-23  \
# 0                                             -0.297658
# 1                                              0.096189
# 2                                             -0.407219
# 3                                             -0.597235
# 4                                              0.116699
# ...                                                 ...
# 3127                                           1.924569
# 3128                                          -2.108917
# 3129                                           1.219039
# 3130                                           1.565607
# 3131                                           1.180534
#
#       Percent of adults with a bachelor's degree or higher, 2019-23  \
# 0                                              0.418089
# 1                                              0.862459
# 2                                             -1.237164
# 3                                             -1.236820
# 4                                             -0.832226
# ...                                                 ...
# 3127                                          -0.360120
# 3128                                           3.659809
# 3129                                          -0.267269
# 3130                                          -0.197078
# 3131                                          -0.589671
#
#       Economic_typology_2015  NATURAL_CHG_2023  DOMESTIC_MIG_2023  \
# 0                  -0.995489         -0.051421           0.125382
# 1                   1.754927         -0.205564           1.747120
# 2                   0.654761         -0.185724          -0.012310
# 3                  -0.995489         -0.160542          -0.018475
# 4                  -0.995489         -0.181909           0.091216
# ...                      ...               ...                ...
# 3127                0.104677         -0.073551          -0.046990
# 3128                1.754927         -0.046079          -0.057523
# 3129                0.104677         -0.086523          -0.006659
# 3130               -0.995489         -0.150622           0.005672
# 3131                0.104677         -0.154438          -0.001521
#
#       R_BIRTH_2023  ...  State_SD  State_TN  State_TX  State_UT  State_VA  \
# 0         0.480823  ...     False     False     False     False     False
# 1        -0.246254  ...     False     False     False     False     False
# 2         0.036498  ...     False     False     False     False     False
# 3         0.076891  ...     False     False     False     False     False
# 4         0.400036  ...     False     False     False     False     False
# ...            ...  ...       ...       ...       ...       ...       ...
# 3127     -0.125074  ...     False     False     False     False     False
# 3128     -1.013723  ...     False     False     False     False     False
# 3129      0.117285  ...     False     False     False     False     False
# 3130     -0.569399  ...     False     False     False     False     False
# 3131     -1.377261  ...     False     False     False     False     False
#
#       State_VT  State_WA  State_WI  State_WV  State_WY
# 0        False     False     False     False     False
# 1        False     False     False     False     False
# 2        False     False     False     False     False
# 3        False     False     False     False     False
# 4        False     False     False     False     False
# ...        ...       ...       ...       ...       ...
# 3127     False     False     False     False      True
# 3128     False     False     False     False      True
# 3129     False     False     False     False      True
# 3130     False     False     False     False      True
# 3131     False     False     False     False      True
#
# [3132 rows x 67 columns]

# %%
filtered = data.drop(['State_AK', 'State_AL',
       'State_AR', 'State_AZ', 'State_CA', 'State_CO', 'State_DC', 'State_DE',
       'State_FL', 'State_GA', 'State_HI', 'State_IA', 'State_ID', 'State_IL',
       'State_IN', 'State_KS', 'State_KY', 'State_LA', 'State_MA', 'State_MD',
       'State_ME', 'State_MI', 'State_MN', 'State_MO', 'State_MS', 'State_MT',
       'State_NC', 'State_ND', 'State_NE', 'State_NH', 'State_NJ', 'State_NM',
       'State_NV', 'State_NY', 'State_OH', 'State_OK', 'State_OR', 'State_PA',
       'State_RI', 'State_SC', 'State_SD', 'State_TN', 'State_TX', 'State_UT',
       'State_VA', 'State_VT', 'State_WA', 'State_WI', 'State_WV', 'State_WY'], axis=1)
filtered.set_index('FIPS', inplace=True)
filtered
# Out:
#        2024 Urban Influence Code  \
# FIPS
# 1001                   -0.426905
# 1003                   -0.426905
# 1005                   -0.037317
# 1007                   -1.595670
# 1009                   -1.595670
# ...                          ...
# 56037                   0.741860
# 56039                   0.741860
# 56041                   0.741860
# 56043                   1.521036
# 56045                   1.521036
#
#        Percent of adults who are not high school graduates, 2019-23  \
# FIPS
# 1001                                           -0.278537
# 1003                                           -0.543725
# 1005                                            1.997280
# 1007                                            1.536006
# 1009                                            1.105865
# ...                                                  ...
# 56037                                          -0.689741
# 56039                                          -1.534765
# 56041                                          -1.068681
# 56043                                          -0.486824
# 56045                                          -0.519879
#
#        Percent of adults who are high school graduates (or equivalent), 2019-23  \
# FIPS
# 1001                                           -0.151198
# 1003                                           -0.822225
# 1005                                            0.493048
# 1007                                            0.953446
# 1009                                            0.233289
# ...                                                  ...
# 56037                                          -0.351006
# 56039                                          -2.311755
# 56041                                           0.281985
# 56043                                          -0.466029
# 56045                                           0.343718
#
#        Percent of adults completing some college or associate degree, 2019-23  \
# FIPS
# 1001                                           -0.297658
# 1003                                            0.096189
# 1005                                           -0.407219
# 1007                                           -0.597235
# 1009                                            0.116699
# ...                                                  ...
# 56037                                           1.924569
# 56039                                          -2.108917
# 56041                                           1.219039
# 56043                                           1.565607
# 56045                                           1.180534
#
#        Percent of adults with a bachelor's degree or higher, 2019-23  \
# FIPS
# 1001                                            0.418089
# 1003                                            0.862459
# 1005                                           -1.237164
# 1007                                           -1.236820
# 1009                                           -0.832226
# ...                                                  ...
# 56037                                          -0.360120
# 56039                                           3.659809
# 56041                                          -0.267269
# 56043                                          -0.197078
# 56045                                          -0.589671
#
#        Economic_typology_2015  NATURAL_CHG_2023  DOMESTIC_MIG_2023  \
# FIPS
# 1001                -0.995489         -0.051421           0.125382
# 1003                 1.754927         -0.205564           1.747120
# 1005                 0.654761         -0.185724          -0.012310
# 1007                -0.995489         -0.160542          -0.018475
# 1009                -0.995489         -0.181909           0.091216
# ...                       ...               ...                ...
# 56037                0.104677         -0.073551          -0.046990
# 56039                1.754927         -0.046079          -0.057523
# 56041                0.104677         -0.086523          -0.006659
# 56043               -0.995489         -0.150622           0.005672
# 56045                0.104677         -0.154438          -0.001521
#
#        R_BIRTH_2023  R_NATURAL_CHG_2023  R_INTERNATIONAL_MIG_2023  \
# FIPS
# 1001       0.480823            0.781117                 -0.333898
# 1003      -0.246254            0.374123                 -0.052500
# 1005       0.036498           -0.268497                 -0.380797
# 1007       0.076891           -0.032870                 -0.615296
# 1009       0.400036            0.181337                 -0.427697
# ...             ...                 ...                       ...
# 56037     -0.125074            0.781117                 -0.755994
# 56039     -1.013723            1.380896                  0.510296
# 56041      0.117285            0.952482                 -0.755994
# 56043     -0.569399           -0.568387                 -0.662195
# 56045     -1.377261           -0.846856                 -0.896693
#
#        R_DOMESTIC_MIG_2023  MEDHHINC_2023  PCTPOVALL_2023  Employed_2023  \
# FIPS
# 1001              0.359741       0.205146       -0.505364      -0.147065
# 1003              1.866632       0.532121       -0.811439       0.310732
# 1005             -0.433359      -1.223756        1.979240      -0.260981
# 1007             -0.536462      -0.573141        0.880973      -0.255145
# 1009              0.185259      -0.031094       -0.307316      -0.153887
# ...                    ...            ...             ...            ...
# 56037            -0.639565       0.665192       -0.811439      -0.188437
# 56039            -1.044046       3.923056       -1.495605      -0.204298
# 56041            -0.377842       0.825556       -0.757425      -0.253626
# 56043            -0.036809      -0.162588       -0.397338      -0.284446
# 56045            -0.322325       0.057883       -0.559377      -0.283968
#
#        Unemployment_rate_2023
# FIPS
# 1001                -1.137550
# 1003                -1.055631
# 1005                 0.664661
# 1007                -0.891794
# 1009                -1.219469
# ...                       ...
# 56037               -0.236445
# 56039               -1.219469
# 56041               -0.318363
# 56043               -0.236445
# 56045               -1.219469
#
# [3132 rows x 16 columns]

# %% [markdown]
# # K-means

# %%
inertia = []
k_range = range(1, 16)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(filtered)
    inertia.append(kmeans.inertia_)

plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(filtered)

filtered['cluster'] = clusters

# %%
cluster_sizes = filtered['cluster'].value_counts()

# Display cluster sizes
print(cluster_sizes)
# Out:
# cluster
# 1    1568
# 2    1039
# 0     501
# 3      24
# Name: count, dtype: int64

# %%
filtered
# Out:
#        2024 Urban Influence Code  \
# FIPS
# 1001                   -0.426905
# 1003                   -0.426905
# 1005                   -0.037317
# 1007                   -1.595670
# 1009                   -1.595670
# ...                          ...
# 56037                   0.741860
# 56039                   0.741860
# 56041                   0.741860
# 56043                   1.521036
# 56045                   1.521036
#
#        Percent of adults who are not high school graduates, 2019-23  \
# FIPS
# 1001                                           -0.278537
# 1003                                           -0.543725
# 1005                                            1.997280
# 1007                                            1.536006
# 1009                                            1.105865
# ...                                                  ...
# 56037                                          -0.689741
# 56039                                          -1.534765
# 56041                                          -1.068681
# 56043                                          -0.486824
# 56045                                          -0.519879
#
#        Percent of adults who are high school graduates (or equivalent), 2019-23  \
# FIPS
# 1001                                           -0.151198
# 1003                                           -0.822225
# 1005                                            0.493048
# 1007                                            0.953446
# 1009                                            0.233289
# ...                                                  ...
# 56037                                          -0.351006
# 56039                                          -2.311755
# 56041                                           0.281985
# 56043                                          -0.466029
# 56045                                           0.343718
#
#        Percent of adults completing some college or associate degree, 2019-23  \
# FIPS
# 1001                                           -0.297658
# 1003                                            0.096189
# 1005                                           -0.407219
# 1007                                           -0.597235
# 1009                                            0.116699
# ...                                                  ...
# 56037                                           1.924569
# 56039                                          -2.108917
# 56041                                           1.219039
# 56043                                           1.565607
# 56045                                           1.180534
#
#        Percent of adults with a bachelor's degree or higher, 2019-23  \
# FIPS
# 1001                                            0.418089
# 1003                                            0.862459
# 1005                                           -1.237164
# 1007                                           -1.236820
# 1009                                           -0.832226
# ...                                                  ...
# 56037                                          -0.360120
# 56039                                           3.659809
# 56041                                          -0.267269
# 56043                                          -0.197078
# 56045                                          -0.589671
#
#        Economic_typology_2015  NATURAL_CHG_2023  DOMESTIC_MIG_2023  \
# FIPS
# 1001                -0.995489         -0.051421           0.125382
# 1003                 1.754927         -0.205564           1.747120
# 1005                 0.654761         -0.185724          -0.012310
# 1007                -0.995489         -0.160542          -0.018475
# 1009                -0.995489         -0.181909           0.091216
# ...                       ...               ...                ...
# 56037                0.104677         -0.073551          -0.046990
# 56039                1.754927         -0.046079          -0.057523
# 56041                0.104677         -0.086523          -0.006659
# 56043               -0.995489         -0.150622           0.005672
# 56045                0.104677         -0.154438          -0.001521
#
#        R_BIRTH_2023  R_NATURAL_CHG_2023  R_INTERNATIONAL_MIG_2023  \
# FIPS
# 1001       0.480823            0.781117                 -0.333898
# 1003      -0.246254            0.374123                 -0.052500
# 1005       0.036498           -0.268497                 -0.380797
# 1007       0.076891           -0.032870                 -0.615296
# 1009       0.400036            0.181337                 -0.427697
# ...             ...                 ...                       ...
# 56037     -0.125074            0.781117                 -0.755994
# 56039     -1.013723            1.380896                  0.510296
# 56041      0.117285            0.952482                 -0.755994
# 56043     -0.569399           -0.568387                 -0.662195
# 56045     -1.377261           -0.846856                 -0.896693
#
#        R_DOMESTIC_MIG_2023  MEDHHINC_2023  PCTPOVALL_2023  Employed_2023  \
# FIPS
# 1001              0.359741       0.205146       -0.505364      -0.147065
# 1003              1.866632       0.532121       -0.811439       0.310732
# 1005             -0.433359      -1.223756        1.979240      -0.260981
# 1007             -0.536462      -0.573141        0.880973      -0.255145
# 1009              0.185259      -0.031094       -0.307316      -0.153887
# ...                    ...            ...             ...            ...
# 56037            -0.639565       0.665192       -0.811439      -0.188437
# 56039            -1.044046       3.923056       -1.495605      -0.204298
# 56041            -0.377842       0.825556       -0.757425      -0.253626
# 56043            -0.036809      -0.162588       -0.397338      -0.284446
# 56045            -0.322325       0.057883       -0.559377      -0.283968
#
#        Unemployment_rate_2023  cluster
# FIPS
# 1001                -1.137550        1
# 1003                -1.055631        1
# 1005                 0.664661        2
# 1007                -0.891794        2
# 1009                -1.219469        1
# ...                       ...      ...
# 56037               -0.236445        1
# 56039               -1.219469        0
# 56041               -0.318363        1
# 56043               -0.236445        1
# 56045               -1.219469        1
#
# [3132 rows x 17 columns]

# %% [markdown]
# # Mapping

# %%
import geopandas as gpd
import json

gdf = gpd.read_file('data/counties_2023.geojson')
gdf = gdf.to_crs('EPSG:4326')
plotly_geojson = json.loads(gdf.set_index('GEOID').to_json())

# %%
# Load and prepare mapping file
fips_mapping = pd.read_csv('data/FipsCountyCodes.csv')
fips_mapping['FIPS'] = fips_mapping['FIPS'].astype(str)

final_df = filtered
# Make sure filtered's index is also string
final_df.index = final_df.index.astype(str)

# Merge using index and keep FIPS as index
final_df = final_df.merge(fips_mapping[['FIPS', 'Name']], left_index=True, right_on='FIPS', how='left')

# Optionally drop the duplicate 'FIPS' column after merge
final_df.set_index('FIPS', inplace=True)

# %%
final_df
# Out:
#        2024 Urban Influence Code  \
# FIPS
# 1001                   -0.426905
# 1003                   -0.426905
# 1005                   -0.037317
# 1007                   -1.595670
# 1009                   -1.595670
# ...                          ...
# 56037                   0.741860
# 56039                   0.741860
# 56041                   0.741860
# 56043                   1.521036
# 56045                   1.521036
#
#        Percent of adults who are not high school graduates, 2019-23  \
# FIPS
# 1001                                           -0.278537
# 1003                                           -0.543725
# 1005                                            1.997280
# 1007                                            1.536006
# 1009                                            1.105865
# ...                                                  ...
# 56037                                          -0.689741
# 56039                                          -1.534765
# 56041                                          -1.068681
# 56043                                          -0.486824
# 56045                                          -0.519879
#
#        Percent of adults who are high school graduates (or equivalent), 2019-23  \
# FIPS
# 1001                                           -0.151198
# 1003                                           -0.822225
# 1005                                            0.493048
# 1007                                            0.953446
# 1009                                            0.233289
# ...                                                  ...
# 56037                                          -0.351006
# 56039                                          -2.311755
# 56041                                           0.281985
# 56043                                          -0.466029
# 56045                                           0.343718
#
#        Percent of adults completing some college or associate degree, 2019-23  \
# FIPS
# 1001                                           -0.297658
# 1003                                            0.096189
# 1005                                           -0.407219
# 1007                                           -0.597235
# 1009                                            0.116699
# ...                                                  ...
# 56037                                           1.924569
# 56039                                          -2.108917
# 56041                                           1.219039
# 56043                                           1.565607
# 56045                                           1.180534
#
#        Percent of adults with a bachelor's degree or higher, 2019-23  \
# FIPS
# 1001                                            0.418089
# 1003                                            0.862459
# 1005                                           -1.237164
# 1007                                           -1.236820
# 1009                                           -0.832226
# ...                                                  ...
# 56037                                          -0.360120
# 56039                                           3.659809
# 56041                                          -0.267269
# 56043                                          -0.197078
# 56045                                          -0.589671
#
#        Economic_typology_2015  NATURAL_CHG_2023  DOMESTIC_MIG_2023  \
# FIPS
# 1001                -0.995489         -0.051421           0.125382
# 1003                 1.754927         -0.205564           1.747120
# 1005                 0.654761         -0.185724          -0.012310
# 1007                -0.995489         -0.160542          -0.018475
# 1009                -0.995489         -0.181909           0.091216
# ...                       ...               ...                ...
# 56037                0.104677         -0.073551          -0.046990
# 56039                1.754927         -0.046079          -0.057523
# 56041                0.104677         -0.086523          -0.006659
# 56043               -0.995489         -0.150622           0.005672
# 56045                0.104677         -0.154438          -0.001521
#
#        R_BIRTH_2023  R_NATURAL_CHG_2023  R_INTERNATIONAL_MIG_2023  \
# FIPS
# 1001       0.480823            0.781117                 -0.333898
# 1003      -0.246254            0.374123                 -0.052500
# 1005       0.036498           -0.268497                 -0.380797
# 1007       0.076891           -0.032870                 -0.615296
# 1009       0.400036            0.181337                 -0.427697
# ...             ...                 ...                       ...
# 56037     -0.125074            0.781117                 -0.755994
# 56039     -1.013723            1.380896                  0.510296
# 56041      0.117285            0.952482                 -0.755994
# 56043     -0.569399           -0.568387                 -0.662195
# 56045     -1.377261           -0.846856                 -0.896693
#
#        R_DOMESTIC_MIG_2023  MEDHHINC_2023  PCTPOVALL_2023  Employed_2023  \
# FIPS
# 1001              0.359741       0.205146       -0.505364      -0.147065
# 1003              1.866632       0.532121       -0.811439       0.310732
# 1005             -0.433359      -1.223756        1.979240      -0.260981
# 1007             -0.536462      -0.573141        0.880973      -0.255145
# 1009              0.185259      -0.031094       -0.307316      -0.153887
# ...                    ...            ...             ...            ...
# 56037            -0.639565       0.665192       -0.811439      -0.188437
# 56039            -1.044046       3.923056       -1.495605      -0.204298
# 56041            -0.377842       0.825556       -0.757425      -0.253626
# 56043            -0.036809      -0.162588       -0.397338      -0.284446
# 56045            -0.322325       0.057883       -0.559377      -0.283968
#
#        Unemployment_rate_2023  cluster            Name
# FIPS
# 1001                -1.137550        1     AL, Autauga
# 1003                -1.055631        1     AL, Baldwin
# 1005                 0.664661        2     AL, Barbour
# 1007                -0.891794        2        AL, Bibb
# 1009                -1.219469        1      AL, Blount
# ...                       ...      ...             ...
# 56037               -0.236445        1  WY, Sweetwater
# 56039               -1.219469        0       WY, Teton
# 56041               -0.318363        1       WY, Uinta
# 56043               -0.236445        1    WY, Washakie
# 56045               -1.219469        1      WY, Weston
#
# [3132 rows x 18 columns]

# %%
cluster_sizes = final_df['cluster'].value_counts()

# Display cluster sizes
print(cluster_sizes)
# Out:
# cluster
# 1    1568
# 2    1039
# 0     501
# 3      24
# Name: count, dtype: int64

# %%
import plotly.io as pio
pio.renderers.default = "browser"

# run this so it doesn't crash

# %%
import plotly.express as px

# Make sure FIPS is a string with 5 digits in the index
final_df.index = final_df.index.astype(str).str.zfill(5)

# Ensure cluster column is string type
final_df['cluster'] = final_df['cluster'].astype(str)

# Sort by cluster for better color grouping
final_df = final_df.sort_values(by='cluster')

# Add FIPS as a column for plotting (Plotly requires a column for `locations`)
filtered_plot = final_df.copy()
filtered_plot["FIPS"] = filtered_plot.index

# Create choropleth
fig = px.choropleth(
    filtered_plot,
    geojson=plotly_geojson,
    locations='FIPS',
    color='cluster',
    color_discrete_sequence=px.colors.qualitative.Plotly,
    scope="usa",
    hover_name='Name',
    title='US County Clusters'
)

fig.update_geos(
    visible=False,
    bgcolor='rgba(0,0,0,0)'
)

fig.update_traces(
    marker_line_width=0.1,
    marker_opacity=0.8,
    hovertemplate="<b>%{customdata[0]}</b><br>" +
                  "FIPS: %{location}<br>" +
                  "Cluster: %{customdata[1]}<extra></extra>",
    customdata=filtered_plot[['Name', 'cluster']].values
)

fig.update_layout(
    height=600,
    width=1000,
    margin={"r": 0, "t": 40, "l": 0, "b": 0},
    legend_title_text='Cluster'
)

fig.show()

# %% [markdown]
# ### output is going to be on browser, but it will look something like this:

# %% [markdown]
# ![IMG_1105.png](attachment:7c13219b-c124-4173-87ca-9abbf0d6b00a.png)

# %%
def recommend_similar_counties(input_value, df, n=5):
    # Ensure index is string and zero-padded
    df.index = df.index.astype(str).str.zfill(5)

    # Determine if input is a county name or FIPS
    if str(input_value).zfill(5) in df.index:
        fips_code = str(input_value).zfill(5)
    elif input_value in df['Name'].values:
        fips_code = df[df['Name'] == input_value].index[0]
    else:
        return f"Input '{input_value}' not found as FIPS or county name."

    input_county_name = df.loc[fips_code, 'Name']
    cluster_id = df.loc[fips_code, 'cluster']

    # Get counties in the same cluster, excluding the input
    same_cluster = df[df['cluster'] == cluster_id].drop(index=fips_code, errors='ignore')

    # Compute Euclidean distances on feature columns
    features = df.columns.difference(['cluster', 'Name'])
    distances = ((same_cluster[features] - df.loc[fips_code, features]) ** 2).sum(axis=1)

    top_matches = distances.sort_values().head(n)

    return {
        "input": (fips_code, input_county_name),
        "recommendations": [(fips, df.loc[fips, 'Name']) for fips in top_matches.index]
    }

# %%
recommend_similar_counties(56039, final_df)
# Out:
# {'input': ('56039', 'WY, Teton'),
#  'recommendations': [('08097', 'CO, Pitkin'),
#   ('08107', 'CO, Routt'),
#   ('08117', 'CO, Summit'),
#   ('49043', 'UT, Summit'),
#   ('08037', 'CO, Eagle')]}

# %%
recommend_similar_counties('CA, Los Angeles', final_df)
# Out:
# {'input': ('06037', 'CA, Los Angeles'),
#  'recommendations': [('17031', 'IL, Cook'),
#   ('36047', 'NY, Kings'),
#   ('48113', 'TX, Dallas'),
#   ('36081', 'NY, Queens'),
#   ('48201', 'TX, Harris')]}

# %%
final_df[final_df.index.to_series().astype(int).between(6000, 6999)]["Name"].to_list()
# Out:
# ['CA, Alameda',
#  'CA, Alpine',
#  'CA, Amador',
#  'CA, Butte',
#  'CA, Calaveras',
#  'CA, Colusa',
#  'CA, Contra Costa',
#  'CA, Del Norte',
#  'CA, El Dorado',
#  'CA, Fresno',
#  'CA, Glenn',
#  'CA, Humboldt',
#  'CA, Imperial',
#  'CA, Inyo',
#  'CA, Kern',
#  'CA, Kings',
#  'CA, Lake',
#  'CA, Lassen',
#  'CA, Los Angeles',
#  'CA, Madera',
#  'CA, Marin',
#  'CA, Mariposa',
#  'CA, Mendocino',
#  'CA, Merced',
#  'CA, Modoc',
#  'CA, Mono',
#  'CA, Monterey',
#  'CA, Napa',
#  'CA, Nevada',
#  'CA, Orange',
#  'CA, Placer',
#  'CA, Plumas',
#  'CA, Riverside',
#  'CA, Sacramento',
#  'CA, San Benito',
#  'CA, San Bernardino',
#  'CA, San Diego',
#  'CA, San Francisco',
#  'CA, San Joaquin',
#  'CA, San Luis Obispo',
#  'CA, San Mateo',
#  'CA, Santa Barbara',
#  'CA, Santa Clara',
#  'CA, Santa Cruz',
#  'CA, Shasta',
#  'CA, Sierra',
#  'CA, Siskiyou',
#  'CA, Solano',
#  'CA, Sonoma',
#  'CA, Stanislaus',
#  'CA, Sutter',
#  'CA, Tehama',
#  'CA, Trinity',
#  'CA, Tulare',
#  'CA, Tuolumne',
#  'CA, Ventura',
#  'CA, Yolo',
#  'CA, Yuba']
